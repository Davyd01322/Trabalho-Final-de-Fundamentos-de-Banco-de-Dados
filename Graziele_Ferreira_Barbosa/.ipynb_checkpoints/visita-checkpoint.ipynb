# %%
import os
from dotenv import load_dotenv

import pandas as pd
import psycopg2 as pg
from sqlalchemy import create_engine, text
import panel as pn

pn.extension()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3d30e5cd-af4f-4c7d-8bf2-13393e6a811b'>
#   <div id="a12debad-9db7-4a30-901e-12fd790cdc80" data-root-id="3d30e5cd-af4f-4c7d-8bf2-13393e6a811b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b0f808bb-8148-4f01-af4e-6c365bd07136":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"7e90471c-b836-4d53-8595-89bcd2ac0249","attributes":{"notifications":{"type":"object","name":"Notifications","id":"50799dd9-4ecb-4552-9f06-b5a5ea161fff"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3d30e5cd-af4f-4c7d-8bf2-13393e6a811b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1be2304a-24d3-4cd4-916b-28a70e7f278f","attributes":{"plot_id":"3d30e5cd-af4f-4c7d-8bf2-13393e6a811b","comm_id":"83692be61f5c48febe4e9a8f75fe9935","client_comm_id":"66ac87975e25487594713cd64a8339ba"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"b0f808bb-8148-4f01-af4e-6c365bd07136","roots":{"3d30e5cd-af4f-4c7d-8bf2-13393e6a811b":"a12debad-9db7-4a30-901e-12fd790cdc80"},"root_ids":["3d30e5cd-af4f-4c7d-8bf2-13393e6a811b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
load_dotenv()

DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")
DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")

DB_NAME
# Out:
# 'tombo_fbd'

# %%
engine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}/{DB_NAME}"
)

# %%
load_dotenv()
# Out:
# True

# %%
query = "SELECT * FROM patrimonio;"
df = pd.read_sql_query(query, engine)

df
# Out:
#    id_patrimonio                                     nome_atribuido  \
# 0              1  Igreja Matriz de São Pedro e Capela da Ordem T...
# 1              3                 Convento e Igreja de Santo Antônio
# 2              4  Igreja de Nossa Senhora da Conceição dos Milit...
# 3              5               Igreja de Nossa Senhora dos Prazeres
# 4              6  Capela dos Noviços da Ordem Terceira de São Fr...
# 5              8     Museu da União dos Caixeiros Viajantes: acervo
# 6              9                     Mosteiro e Igreja de São Bento
# 7             10            Casa na Ladeira do Morro do Valongo, 21
# 8             11  Asilo São Cornélio: prédio (Casa à Rua do Cate...
# 9             12     Hospital da Santa Casa de Misericórdia: prédio
#
#                      tipo   grupo       codigo_sicg_iphan estado_preservacao  \
# 0              Edificação  Nenhum      RS4315602BIED00002     Pouco Alterado
# 1  Conjunto Arquitetônico  Nenhum  PE-2607208-BI-CA-00001     Pouco Alterado
# 2              Edificação  Nenhum  PE-2611606-BI-ED-00028            Integro
# 3              Edificação  Nenhum  PE-2607901-BI-ED-00002            Integro
# 4              Edificação  Nenhum  PE-2611606-BI-ED-00003     Pouco Alterado
# 5                 Coleção  Nenhum  RS-4316907-BM-CL-00001     Pouco Alterado
# 6              Edificação  Nenhum  RJ-3304557-BI-ED-00021            Integro
# 7              Edificação  Nenhum  RJ-3304557-BI-ED-00075     Muito Alterado
# 8              Edificação  Nenhum  RJ-3304557-BI-ED-00078     Muito Alterado
# 9              Edificação  Nenhum  RJ-3304557-BI-ED-00049     Pouco Alterado
#
#   estagio_instrucao estado_conservacao uso_do_solo processo_administrativo  \
# 0           Tombado            Regular      Urbano                    None
# 1           Tombado            Regular      Urbano                    None
# 2           Tombado                Bom      Urbano                    None
# 3           Tombado                Bom      Urbano                    None
# 4           Tombado            Regular      Urbano                    None
# 5           Tombado            Regular      Urbano                    None
# 6           Tombado                Bom      Urbano                    None
# 7           Tombado               Ruim      Urbano                    None
# 8           Tombado            Péssimo      Urbano                    None
# 9           Tombado            Péssimo      Urbano                    None
#
#   localizacao_processo  ano_de_abertura                 natureza   entorno  \
# 0              Arquivo             1938               Bem imovel  Alterado
# 1              Arquivo             1938               Bem imovel  Alterado
# 2              Arquivo             1938               Bem imovel  Alterado
# 3              Arquivo             1938               Bem imovel  Alterado
# 4              Arquivo             1938               Bem imovel  Alterado
# 5              Arquivo             1938  Bem imovel ou integrado  Alterado
# 6              Arquivo             1938               Bem imovel  Alterado
# 7              Arquivo             1938               Bem imovel  Alterado
# 8              Arquivo             1938               Bem imovel  Alterado
# 9              Arquivo             1938               Bem imovel  Alterado
#
#   propriedade responsavel_tecnico_cpf id_visita nome_orgao_responsavel
# 0     Publico                    None      None                   None
# 1     Privado                    None      None                   None
# 2     Privado                    None      None                   None
# 3     Privado                    None      None                   None
# 4     Privado                    None      None                   None
# 5     Privado                    None      None                   None
# 6     Privado                    None      None                   None
# 7     Privado                    None      None                   None
# 8     Privado                    None      None                   None
# 9     Privado                    None      None                   None

# %%
pn.extension()
pn.extension('tabulator')
pn.extension(notifications=True)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0a47604b-4b3d-4033-b9c5-49f190116de8'>
#   <div id="fb247c6a-5004-4091-893a-4c4f929b57f0" data-root-id="0a47604b-4b3d-4033-b9c5-49f190116de8" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5af4a467-a0f8-4bbd-a7ca-c36f3b343c8e":{"version":"3.8.1","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"117ee6fd-04e6-4c92-a62c-f35fe399b780","attributes":{"notifications":{"type":"object","name":"Notifications","id":"9eef3a62-aa56-4905-a40e-82a6ff947702"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0a47604b-4b3d-4033-b9c5-49f190116de8"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"4e03b0df-69e7-4a34-a9c2-4178b077ddf6","attributes":{"plot_id":"0a47604b-4b3d-4033-b9c5-49f190116de8","comm_id":"9744174e33e8496682642fea032654b9","client_comm_id":"a943daf844ed4caa84ed2a3f05e28f76"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"5af4a467-a0f8-4bbd-a7ca-c36f3b343c8e","roots":{"0a47604b-4b3d-4033-b9c5-49f190116de8":"fb247c6a-5004-4091-893a-4c4f929b57f0"},"root_ids":["0a47604b-4b3d-4033-b9c5-49f190116de8"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
pn.widgets.Tabulator(df, pagination='remote', page_size=10)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'9843e317-2a70-4bab-a116-bc8199bb4d5d': {'version…

# %%
pn.Column(
    "# Dados da tabela patrimonio",
    pn.widgets.Tabulator(df)
)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'ed3b7437-1ce4-41a3-9262-48ac44a572ca': {'version…

# %% [markdown]
# CREATE	Cadastrar nova visita cultural
# READ	Listar visitas cadastradas
# UPDATE	Alterar data, horário, nº visitantes
# DELETE	Excluir uma visita

# %%
id_visita = pn.widgets.IntInput(name="ID da Visita")

data = pn.widgets.DatePicker(name="Data da Visita")

horario_entrada = pn.widgets.TextInput(
    name="Horário de Entrada", placeholder="HH:MM"
)

horario_saida = pn.widgets.TextInput(
    name="Horário de Saída", placeholder="HH:MM"
)

num_visitantes = pn.widgets.IntInput(
    name="Número de Visitantes", start=1
)

# %%
def criar_visita(event):
    query = text("""
        INSERT INTO visita_cultural
        (id_visita, horario_entrada, horario_saida, data_, num_visitantes)
        VALUES (:id, :he, :hs, :data, :num)
    """)

    try:
        with engine.begin() as conn:
            conn.execute(query, {
                "id": id_visita.value,
                "he": horario_entrada.value,
                "hs": horario_saida.value,
                "data": data.value,
                "num": num_visitantes.value
            })

        pn.state.notifications.success("Visita cadastrada com sucesso!")

    except Exception as e:
        pn.state.notifications.error(str(e))

# %%
btn_criar = pn.widgets.Button(
    name="Cadastrar Visita",
    button_type="primary"
)

btn_criar.on_click(criar_visita)
# Out:
# Watcher(inst=Button(button_type='primary', name='Cadastrar Visita'), cls=<class 'panel.widgets.button.Button'>, fn=<function criar_visita at 0x000002617BE03420>, mode='args', onlychanged=False, parameter_names=('clicks',), what='value', queued=False, precedence=0)

# %%
def listar_visitas():
    df = pd.read_sql(
        "SELECT * FROM visita_cultural ORDER BY data_",
        engine
    )
    return pn.widgets.Tabulator(df, pagination='remote', page_size=5)

# %%
def atualizar_visita(event):
    query = text("""
        UPDATE visita_cultural
        SET horario_entrada = :he,
            horario_saida = :hs,
            data_ = :data,
            num_visitantes = :num
        WHERE id_visita = :id
    """)

    try:
        with engine.begin() as conn:
            conn.execute(query, {
                "id": id_visita.value,
                "he": horario_entrada.value,
                "hs": horario_saida.value,
                "data": data.value,
                "num": num_visitantes.value
            })

        pn.state.notifications.success("Visita atualizada!")

    except Exception as e:
        pn.state.notifications.error(str(e))

# %%
btn_update = pn.widgets.Button(
    name="Atualizar Visita",
    button_type="warning"
)

btn_update.on_click(atualizar_visita)
# Out:
# Watcher(inst=Button(button_type='warning', name='Atualizar Visita'), cls=<class 'panel.widgets.button.Button'>, fn=<function atualizar_visita at 0x000002617BC43740>, mode='args', onlychanged=False, parameter_names=('clicks',), what='value', queued=False, precedence=0)

# %%
def deletar_visita(event):
    try:
        with engine.begin() as conn:
            conn.execute(
                text("DELETE FROM visita_cultural WHERE id_visita = :id"),
                {"id": id_visita.value}
            )

        pn.state.notifications.success("Visita removida!")

    except Exception as e:
        pn.state.notifications.error(str(e))

# %%
btn_delete = pn.widgets.Button(
    name="Excluir Visita",
    button_type="danger"
)

btn_delete.on_click(deletar_visita)
# Out:
# Watcher(inst=Button(button_type='danger', name='Excluir Visita'), cls=<class 'panel.widgets.button.Button'>, fn=<function deletar_visita at 0x000002617BE02DE0>, mode='args', onlychanged=False, parameter_names=('clicks',), what='value', queued=False, precedence=0)

# %%
app = pn.Column(
    "# CRUD – Visita Cultural",
    id_visita,
    data,
    horario_entrada,
    horario_saida,
    num_visitantes,
    pn.Row(btn_criar, btn_update, btn_delete),
    "## Visitas cadastradas",
    listar_visitas()
)

app.servable()
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'b794a486-8ea8-431e-8d24-05978c456bba': {'version…
